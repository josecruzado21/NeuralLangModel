# %%
from nltk.tokenize import RegexpTokenizer
import nltk
from nltk.corpus import brown
import os

# %% [markdown]
# # Importing the Brown corpus from NLTK

# %%
# Donwload NLTK Brown corpus
nltk.download('brown', download_dir='../data/nltk_data')

brown_words_nltk = brown.words()
# Out:
# [nltk_data] Downloading package brown to ../data/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.

# %% [markdown]
# # Loading Brown corpus from texts files downloaded online
#
# Source: https://www.nltk.org/nltk_data/
#
# The idea is to simulate the process of gathering data from corpus of text files and preprocessing it for NLP tasks.

# %%
brown_words_downloaded = []
tokenizer = RegexpTokenizer(r'\S+(?=/)')
folder_path = "../data/brown"
for file in sorted(os.listdir(folder_path)):
    with open(f'{folder_path}/{file}', 
              encoding='utf-8') as file:
        content = file.read()
        words_brown_processed = tokenizer.tokenize(content)
        brown_words_downloaded.extend(words_brown_processed)

# %%
brown_words_downloaded
# Out:
# ['The',
#  'Fulton',
#  'County',
#  'Grand',
#  'Jury',
#  'said',
#  'Friday',
#  'an',
#  'investigation',
#  'of',
#  "Atlanta's",
#  'recent',
#  'primary',
#  'election',
#  'produced',
#  '``',
#  'no',
#  'evidence',
#  "''",
#  'that',
#  'any',
#  'irregularities',
#  'took',
#  'place',
#  '.',
#  'The',
#  'jury',
#  'further',
#  'said',
#  'in',
#  'term-end',
#  'presentments',
#  'that',
#  'the',
#  'City',
#  'Executive',
#  'Committee',
#  ',',
#  'which',
#  'had',
#  'over-all',
#  'charge',
#  'of',
#  'the',
#  'election',
#  ',',
#  '``',
#  'deserves',
#  'the',
#  'praise',
#  'and',
#  'thanks',
#  'of',
#  'the',
#  'City',
#  'of',
#  'Atlanta',
#  "''",
#  'for',
#  'the',
#  'manner',
#  'in',
#  'which',
#  'the',
#  'election',
#  'was',
#  'conducted',
#  '.',
#  'The',
#  'September-October',
#  'term',
#  'jury',
#  'had',
#  'been',
#  'charged',
#  'by',
#  'Fulton',
#  'Superior',
#  'Court',
#  'Judge',
#  'Durwood',
#  'Pye',
#  'to',
# ...

# %%
print(f"Number of words in NLTK Brown corpus: {len(brown_words_nltk):,}")
print(f"Number of words in downloaded Brown corpus: {len(brown_words_downloaded):,}")
# Out:
# Number of words in NLTK Brown corpus: 1,161,192
# Number of words in downloaded Brown corpus: 1,161,192
